# %% [markdown]
# # Analysis Summary
#
# ## Questions
# Question 1: What are the top 20 Italian restaurants by price and rating in Denver, Northern Colorado and Colorado Springs?
#
# Question 2: What was the average rating and price of restaurants by city in order to determine if one metro area had better offerings, in terms of Italian food, than others?
#
# Question 3: Is there any correlation between price and rating? If a restaurant has a pricier cuisine, is it going to bring in higher ratings?
#
# ## Hypothesis
# The hypothesis was that Denver might have more to offer than Colorado Springs and Northern Colorado.
#
# ## Conclusion:
# Overall, in reviewing the top 20 Italian restaurants per city, we found a combination of pizza places, sandwich shops and more upscale restaurants. Denver had the most variety in terms of price, ratings and cuisine type. Denver also tended to have more higher priced options as well as higher rated restaurants overall. There is minimal correlation between rating and price between all cities. There was some relationship between price and rating in restaurants in Denver suggesting that lower priced restaurants were more likely to get higher reviews. The highest rated and highest priced restuarants are in Denver. See notes per each graph below.

# %% [markdown]
# # Question 1
#
# What are the top 20 Italian restaurants by price and rating in Denver, Northern Colorado and Colorado Springs?

# %% [markdown]
# ![Den_Ital_Rating.png](attachment:Den_Ital_Rating.png)!

# %% [markdown]
# In the Denver Italian Restuarants by Rating chart, we see the ratings for the top 20 Denver Italian restaurants range from 4.2 to 4.8 with the most common rating being 4.4.

# %% [markdown]
# ![Den_Ital_Price.png](attachment:Den_Ital_Price.png)

# %% [markdown]
# The Denver Italian Restaurants By Price chart shows a variable price range for the top 20 Italian restaurants in Denver. Prices ranged from 10 to 80 dollars with most restaurants falling within the $25 price range.

# %% [markdown]
# ![CS_Ital_Rating.png](attachment:CS_Ital_Rating.png)

# %% [markdown]
# The Colorado Springs Italian Restaurants By Rating graph shows a limited range of ratings from 4.0 to 4.4. This graph suggests that the quality of restaurants in Denver is higher than in Colorado Springs.

# %% [markdown]
# ![CS_Ital_Price.png](attachment:CS_Ital_Price.png)

# %% [markdown]
# The Colorado Springs Italian Restaurants by Price shows the cost of an average meal ranges from 10 to 40 dollars, with most restaurants falling within the $10 price range. Prices for restaurants in Colorado Springs seems to be less than prices in Denver.

# %% [markdown]
# ![NoCo_Ital_Rating.png](attachment:NoCo_Ital_Rating.png)

# %% [markdown]
# The Northern Colorado Italian Restaurants By Rating show the most variability in ratings for the top 20 Italian restaurants. The ratings ranged from 3.8 to 4.8, suggesting limited quality restaurants for Italian in Northern Colorado when compared to Denver and Colorado Springs.

# %% [markdown]
# ![NoCo_Ital_Price.png](attachment:NoCo_Ital_Price.png)

# %% [markdown]
# The Northern CO Italian Restaurants By Price chart shows that most restaurants in Northern Colorado are at or below the $25 price range. This chart suggests that the price of Italian food in Colorado Springs and Northern Colorado is somewhat similar while Denver has more higher priced restaurants.

# %% [markdown]
# # Question 2
#
# What was the average rating and price of restaurants by city in order to determine if one metro area had better offerings, in terms of Italian food, than others?

# %% [markdown]
# ![City_Ital_Rating.png](attachment:City_Ital_Rating.png)

# %% [markdown]
# The Comparative Average Ratings By City chart shows fairly consistent ratings across Colorado Springs, Denver, and Northern Colorado restaurants. However, Denver shows the highest ratings and Northern Colorado shows the lowest ratings.

# %% [markdown]
# ![City_Ital_Price.png](attachment:City_Ital_Price.png)

# %% [markdown]
# The Comparative Average Price By City shows Denver with the most high-priced restaurants and Colorado Springs with the least expensive restaurants overall.

# %% [markdown]
# # Question 3
#
# Is there any correlation between price and rating? If a restaurant has a pricier cuisine, is it going to bring in higher ratings?

# %% [markdown]
# ![City_RatingvsPrice.png](attachment:City_RatingvsPrice.png)

# %% [markdown]
# The Comparative Rating/Price By City chart shows that there is not a signficant relationship between price and rating when looking at the top 20 highest rated Italian restaurants in Denver, Colorado Springs, and Northern Colorado. However, when looking at Denver restaurants, there is a slight trend toward restaurants with lower prices having higher ratings.
